# %% [markdown]
# In the 'markdown cell' below  replace the `???` with the names of those in your group.

# %% [markdown]
# Group 16: Kotha Shruthi, Mei Li, Lingxiao Li

# %% [markdown]
# # Assignment (part 2): classification of cell morphological changes with ResNet
# _by Phil Harrison (February 2021)_

# %% [markdown]
# ## Load packages

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TensorFlow and Keras
import tensorflow as tf
from tensorflow.keras import models, layers, optimizers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Helper libraries
import random
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.utils import class_weight
import pandas as pd
from PIL import Image

from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ## Functions
# Don't worry too much about the code in the functions below, but you might want to go through when they are called later on so that you roughly understand what they're doing.

# %%
def load_dataset():
    dirname = 'bbbc021v1_images'
    x_orig = np.zeros((660, 256, 256, 3), dtype=np.float32)

    for f in range(x_orig.shape[0]):
        img    = Image.open(dirname + '/bbbc021v1_%s.png' % str(f))
        img    = np.array(img)
        x_orig[f] = img

    labels = pd.read_csv('bbbc021v1_labels.csv',
                          usecols=["compound", "concentration", "moa"],
                          sep=";")
    y_orig = np.array(labels['moa'])

    return x_orig, y_orig

def convert_to_one_hot(y, C):
    moa_dict = {'Aurora kinase inhibitors': 0, 'Cholesterol-lowering': 1,
                'Eg5 inhibitors': 2, 'Protein synthesis': 3, 'DNA replication': 4, 'DNA damage': 5}

    y = np.asarray([moa_dict[item] for item in y])
    y = np.eye(C)[y]
    y = y.astype('float32')

    return y

def plot_history(model_history, model_name):
    fig = plt.figure(figsize=(15, 5), facecolor='w')
    ax = fig.add_subplot(131)
    ax.plot(model_history.history['loss'])
    ax.plot(model_history.history['val_loss'])
    ax.set(title=model_name + ': Model loss', ylabel='Loss', xlabel='Epoch')
    ax.legend(['train', 'valid'], loc='upper right')
    
    ax = fig.add_subplot(132)
    ax.plot(np.log(model_history.history['loss']))
    ax.plot(np.log(model_history.history['val_loss']))
    ax.set(title=model_name + ': Log model loss', ylabel='Log loss', xlabel='Epoch')
    ax.legend(['Train', 'Test'], loc='upper right')    

    ax = fig.add_subplot(133)
    ax.plot(model_history.history['accuracy'])
    ax.plot(model_history.history['val_accuracy'])
    ax.set(title=model_name + ': Model accuracy', ylabel='Accuracy', xlabel='Epoch')
    ax.legend(['train', 'valid'], loc='upper right')
    plt.show()
    plt.close()

def plot_confusion_matrix(cm, classes, model_name,
                          cmap=plt.cm.Blues):
    title = model_name + ': Confusion Matrix'
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    
def valid_evaluate(model, model_name):
    y_pred = model.predict(X_valid)
    y_pred = y_pred.argmax(axis=-1)
    y_true = Y_valid.argmax(axis=-1)
    
    class_names = ['Aur', 'Ch', 'Eg5', 'PS', 'DR', 'DS']
    cnf_matrix = confusion_matrix(y_true, y_pred)
    np.set_printoptions(precision=2)
    plt.figure(figsize=(15,5), facecolor='w')
    plot_confusion_matrix(cnf_matrix, classes=class_names, model_name=model_name)
    plt.show()
    plt.close()
    
    print('')
    print('classification report for validation data:')
    print(classification_report(y_true, y_pred, digits=3))

# %% [markdown]
# ## Read in and preprocess the data

# %%
X_orig, y_orig = load_dataset()
Y = convert_to_one_hot(y_orig, 6)
X = X_orig/255.

n_train = 500

random.seed(5026)
indices = np.arange(len(Y))
random.shuffle(indices)

X_train, X_valid = X[indices[:n_train]], X[indices[n_train:]]
Y_train, Y_valid = Y[indices[:n_train]], Y[indices[n_train:]]

# %% [markdown]
# ## ResNet - a deep residual CNN
# In this section you will implement a deeper state-of-the-art CNN. Specifically, the CNN that you will implement is not too different from the residual CNN presented by He _et al._ (https://arxiv.org/pdf/1512.03385.pdf).
#
# A deep residual network contains dozens of residual blocks (see Figure 1) with intermediate normalization.
#
# <p>
#     <img src="figs/residual_block.png" alt="drawing" style="width:400px;"/>
#     <center>Figure 1. A residual block - the building block of a residual network.</center>
# </p>
#
# The identity mapping is often called a _skip-connection_ or _shortcut_ and has shown to assist in avoiding the degrading effect of training very deep networks --- a degrading effect that is most apparent for "plain" networks. Thus, the residual implementation made it possible to successfully train a very deep CNN that outperformed all the other CNNs that came before.
#
# <p>
#     <img src="figs/resnet.png" alt="drawing" style="width:1200px;"/>
#     <center>Figure 2. Example of a ResNet architecture.</center>
# </p>
#
# ### Batch-normalization
#
# Normalization of input can help in improving neural networks. The idea of batch-normalization is to take this normalization to the intermediate layers. Specifically, batch-normalization normalizes the layer's output before it goes through the activation function (hence we no longer do activation within the convolutional layer, but have an additional layer for this). This can make the neural network more stable and faster at training.
#
# Note: although people sometimes use batch normalization and dropout in the same network, these two approaches can sometimes interfere with one another. Hence we will not use dropout in our ResNet models.

# %% [markdown]
# ## Useful ResNet functions
# Fill in the `???` in the code below (based on the guidance given after them).

# %%
def conv(inputs, num_filters, strides):
    x = layers.Conv2D(num_filters, kernel_size=(3, 3), strides=strides, padding='same',
                      kernel_initializer='he_normal', kernel_regularizer=l2(1e-4))(inputs)
    return x

def ResNet_block(inputs, num_filters, strides):
    x = conv(inputs, num_filters=num_filters, strides=strides)
    x = layers.BatchNormalization(axis=3)(x) # add batch normalisation
    x = layers.Activation('relu')(x) # add a relu activation
    x = conv(x, num_filters=num_filters, strides=1)
    x = layers.BatchNormalization(axis=3)(x) # add batch normalisation
    x = layers.Activation('relu')(x)
    if strides > 1:
        y = conv(inputs, num_filters=num_filters, strides=strides)
        y = layers.BatchNormalization(axis=3)(y) # add batch normalisation (for y this time)
        y = layers.Activation('relu')(y)
    else:
        y = inputs
    z = layers.add([x, y])
    z = layers.Activation('relu')(z)
    return z

# %% [markdown]
# ## Define ResNet model
# Coding ResNet is rather more involved than LeNet. Note, Figure 2 is simply for illustrative purposes, the number of filters there, blocks per stack etc., is different to what we would like you to implement. Your task is to fill in the `???` again (based on the guidance given after them) and then jot down the architecture of the model based on the code in this cell and the one above (keep this succinct, i.e. don't try to write what's going on in every layer, or you'll be here all day (!), just jot down the basics in terms of how it is structured). Once you've done that, run the cell and compare your output with ours.
#
# Hint: again look to the code given in the lectures for guidance here.

# %%
num_classes = 6
inps = layers.Input((256, 256, 3))
x = layers.Conv2D(32, kernel_size=(5, 5), strides=2, padding='same',
                 kernel_initializer='he_normal', kernel_regularizer=l2(1e-4))(inps)

x = layers.BatchNormalization(axis=3)(x) # add batch normalisation
x = layers.Activation('relu')(x) # add a relu activation
x = layers.MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(x) # add max pooling (3x3, with a stride of 2 and 'same' padding)

num_stacks = 3
num_blocks_per_stack = [3, 4, 3]
num_filters_in_stack = [64, 128, 256]

for i in range(num_stacks):
    num_filters = num_filters_in_stack[i]
    for j in range(num_blocks_per_stack[i]):
        if(j == 0):
            strides = 2
        else:
            strides = 1
        x = ResNet_block(x, num_filters=num_filters, strides=strides)  # call the ResNet_block function here with the apprporate inputs
        # hint for the call above, look to where we call the conv function within the ResNet block 

x = layers.GlobalAveragePooling2D()(x) # add global average pooling
preds = layers.Dense(6, activation='softmax')(x) # define a softmax dense output layer (named "preds")

ResNet = models.Model(inputs=inps, outputs=preds)
ResNet.summary()
# Out:
# Model: "model_25"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_57 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_889 (Conv2D)             (None, 128, 128, 32) 2432        input_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_883 (BatchN (None, 128, 128, 32) 128         conv2d_889[0][0]
# __________________________________________________________________________________________________
# activation_1233 (Activation)    (None, 128, 128, 32) 0           batch_normalization_883[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_44 (MaxPooling2D) (None, 64, 64, 32)   0           activation_1233[0][0]
# __________________________________________________________________________________________________
# conv2d_890 (Conv2D)             (None, 32, 32, 64)   18496       max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_884 (BatchN (None, 32, 32, 64)   256         conv2d_890[0][0]
# __________________________________________________________________________________________________
# activation_1234 (Activation)    (None, 32, 32, 64)   0           batch_normalization_884[0][0]
# __________________________________________________________________________________________________
# conv2d_891 (Conv2D)             (None, 32, 32, 64)   36928       activation_1234[0][0]
# __________________________________________________________________________________________________
# conv2d_892 (Conv2D)             (None, 32, 32, 64)   18496       max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_885 (BatchN (None, 32, 32, 64)   256         conv2d_891[0][0]
# __________________________________________________________________________________________________
# batch_normalization_886 (BatchN (None, 32, 32, 64)   256         conv2d_892[0][0]
# __________________________________________________________________________________________________
# activation_1235 (Activation)    (None, 32, 32, 64)   0           batch_normalization_885[0][0]
# __________________________________________________________________________________________________
# activation_1236 (Activation)    (None, 32, 32, 64)   0           batch_normalization_886[0][0]
# __________________________________________________________________________________________________
# add_357 (Add)                   (None, 32, 32, 64)   0           activation_1235[0][0]
#                                                                  activation_1236[0][0]
# __________________________________________________________________________________________________
# activation_1237 (Activation)    (None, 32, 32, 64)   0           add_357[0][0]
# __________________________________________________________________________________________________
# conv2d_893 (Conv2D)             (None, 32, 32, 64)   36928       activation_1237[0][0]
# __________________________________________________________________________________________________
# batch_normalization_887 (BatchN (None, 32, 32, 64)   256         conv2d_893[0][0]
# __________________________________________________________________________________________________
# activation_1238 (Activation)    (None, 32, 32, 64)   0           batch_normalization_887[0][0]
# __________________________________________________________________________________________________
# conv2d_894 (Conv2D)             (None, 32, 32, 64)   36928       activation_1238[0][0]
# __________________________________________________________________________________________________
# batch_normalization_888 (BatchN (None, 32, 32, 64)   256         conv2d_894[0][0]
# __________________________________________________________________________________________________
# activation_1239 (Activation)    (None, 32, 32, 64)   0           batch_normalization_888[0][0]
# __________________________________________________________________________________________________
# add_358 (Add)                   (None, 32, 32, 64)   0           activation_1239[0][0]
#                                                                  activation_1237[0][0]
# __________________________________________________________________________________________________
# activation_1240 (Activation)    (None, 32, 32, 64)   0           add_358[0][0]
# __________________________________________________________________________________________________
# conv2d_895 (Conv2D)             (None, 32, 32, 64)   36928       activation_1240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_889 (BatchN (None, 32, 32, 64)   256         conv2d_895[0][0]
# __________________________________________________________________________________________________
# activation_1241 (Activation)    (None, 32, 32, 64)   0           batch_normalization_889[0][0]
# __________________________________________________________________________________________________
# conv2d_896 (Conv2D)             (None, 32, 32, 64)   36928       activation_1241[0][0]
# __________________________________________________________________________________________________
# batch_normalization_890 (BatchN (None, 32, 32, 64)   256         conv2d_896[0][0]
# __________________________________________________________________________________________________
# activation_1242 (Activation)    (None, 32, 32, 64)   0           batch_normalization_890[0][0]
# __________________________________________________________________________________________________
# add_359 (Add)                   (None, 32, 32, 64)   0           activation_1242[0][0]
#                                                                  activation_1240[0][0]
# __________________________________________________________________________________________________
# activation_1243 (Activation)    (None, 32, 32, 64)   0           add_359[0][0]
# __________________________________________________________________________________________________
# conv2d_897 (Conv2D)             (None, 16, 16, 128)  73856       activation_1243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_891 (BatchN (None, 16, 16, 128)  512         conv2d_897[0][0]
# __________________________________________________________________________________________________
# activation_1244 (Activation)    (None, 16, 16, 128)  0           batch_normalization_891[0][0]
# __________________________________________________________________________________________________
# conv2d_898 (Conv2D)             (None, 16, 16, 128)  147584      activation_1244[0][0]
# __________________________________________________________________________________________________
# conv2d_899 (Conv2D)             (None, 16, 16, 128)  73856       activation_1243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_892 (BatchN (None, 16, 16, 128)  512         conv2d_898[0][0]
# __________________________________________________________________________________________________
# batch_normalization_893 (BatchN (None, 16, 16, 128)  512         conv2d_899[0][0]
# __________________________________________________________________________________________________
# activation_1245 (Activation)    (None, 16, 16, 128)  0           batch_normalization_892[0][0]
# __________________________________________________________________________________________________
# activation_1246 (Activation)    (None, 16, 16, 128)  0           batch_normalization_893[0][0]
# __________________________________________________________________________________________________
# add_360 (Add)                   (None, 16, 16, 128)  0           activation_1245[0][0]
#                                                                  activation_1246[0][0]
# __________________________________________________________________________________________________
# activation_1247 (Activation)    (None, 16, 16, 128)  0           add_360[0][0]
# __________________________________________________________________________________________________
# conv2d_900 (Conv2D)             (None, 16, 16, 128)  147584      activation_1247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_894 (BatchN (None, 16, 16, 128)  512         conv2d_900[0][0]
# __________________________________________________________________________________________________
# activation_1248 (Activation)    (None, 16, 16, 128)  0           batch_normalization_894[0][0]
# __________________________________________________________________________________________________
# conv2d_901 (Conv2D)             (None, 16, 16, 128)  147584      activation_1248[0][0]
# __________________________________________________________________________________________________
# batch_normalization_895 (BatchN (None, 16, 16, 128)  512         conv2d_901[0][0]
# __________________________________________________________________________________________________
# activation_1249 (Activation)    (None, 16, 16, 128)  0           batch_normalization_895[0][0]
# __________________________________________________________________________________________________
# add_361 (Add)                   (None, 16, 16, 128)  0           activation_1249[0][0]
#                                                                  activation_1247[0][0]
# __________________________________________________________________________________________________
# activation_1250 (Activation)    (None, 16, 16, 128)  0           add_361[0][0]
# __________________________________________________________________________________________________
# conv2d_902 (Conv2D)             (None, 16, 16, 128)  147584      activation_1250[0][0]
# __________________________________________________________________________________________________
# batch_normalization_896 (BatchN (None, 16, 16, 128)  512         conv2d_902[0][0]
# __________________________________________________________________________________________________
# activation_1251 (Activation)    (None, 16, 16, 128)  0           batch_normalization_896[0][0]
# __________________________________________________________________________________________________
# conv2d_903 (Conv2D)             (None, 16, 16, 128)  147584      activation_1251[0][0]
# __________________________________________________________________________________________________
# batch_normalization_897 (BatchN (None, 16, 16, 128)  512         conv2d_903[0][0]
# __________________________________________________________________________________________________
# activation_1252 (Activation)    (None, 16, 16, 128)  0           batch_normalization_897[0][0]
# __________________________________________________________________________________________________
# add_362 (Add)                   (None, 16, 16, 128)  0           activation_1252[0][0]
#                                                                  activation_1250[0][0]
# __________________________________________________________________________________________________
# activation_1253 (Activation)    (None, 16, 16, 128)  0           add_362[0][0]
# __________________________________________________________________________________________________
# conv2d_904 (Conv2D)             (None, 16, 16, 128)  147584      activation_1253[0][0]
# __________________________________________________________________________________________________
# batch_normalization_898 (BatchN (None, 16, 16, 128)  512         conv2d_904[0][0]
# __________________________________________________________________________________________________
# activation_1254 (Activation)    (None, 16, 16, 128)  0           batch_normalization_898[0][0]
# __________________________________________________________________________________________________
# conv2d_905 (Conv2D)             (None, 16, 16, 128)  147584      activation_1254[0][0]
# __________________________________________________________________________________________________
# batch_normalization_899 (BatchN (None, 16, 16, 128)  512         conv2d_905[0][0]
# __________________________________________________________________________________________________
# activation_1255 (Activation)    (None, 16, 16, 128)  0           batch_normalization_899[0][0]
# __________________________________________________________________________________________________
# add_363 (Add)                   (None, 16, 16, 128)  0           activation_1255[0][0]
#                                                                  activation_1253[0][0]
# __________________________________________________________________________________________________
# activation_1256 (Activation)    (None, 16, 16, 128)  0           add_363[0][0]
# __________________________________________________________________________________________________
# conv2d_906 (Conv2D)             (None, 8, 8, 256)    295168      activation_1256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_900 (BatchN (None, 8, 8, 256)    1024        conv2d_906[0][0]
# __________________________________________________________________________________________________
# activation_1257 (Activation)    (None, 8, 8, 256)    0           batch_normalization_900[0][0]
# __________________________________________________________________________________________________
# conv2d_907 (Conv2D)             (None, 8, 8, 256)    590080      activation_1257[0][0]
# __________________________________________________________________________________________________
# conv2d_908 (Conv2D)             (None, 8, 8, 256)    295168      activation_1256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_901 (BatchN (None, 8, 8, 256)    1024        conv2d_907[0][0]
# __________________________________________________________________________________________________
# batch_normalization_902 (BatchN (None, 8, 8, 256)    1024        conv2d_908[0][0]
# __________________________________________________________________________________________________
# activation_1258 (Activation)    (None, 8, 8, 256)    0           batch_normalization_901[0][0]
# __________________________________________________________________________________________________
# activation_1259 (Activation)    (None, 8, 8, 256)    0           batch_normalization_902[0][0]
# __________________________________________________________________________________________________
# add_364 (Add)                   (None, 8, 8, 256)    0           activation_1258[0][0]
#                                                                  activation_1259[0][0]
# __________________________________________________________________________________________________
# activation_1260 (Activation)    (None, 8, 8, 256)    0           add_364[0][0]
# __________________________________________________________________________________________________
# conv2d_909 (Conv2D)             (None, 8, 8, 256)    590080      activation_1260[0][0]
# __________________________________________________________________________________________________
# batch_normalization_903 (BatchN (None, 8, 8, 256)    1024        conv2d_909[0][0]
# __________________________________________________________________________________________________
# activation_1261 (Activation)    (None, 8, 8, 256)    0           batch_normalization_903[0][0]
# __________________________________________________________________________________________________
# conv2d_910 (Conv2D)             (None, 8, 8, 256)    590080      activation_1261[0][0]
# __________________________________________________________________________________________________
# batch_normalization_904 (BatchN (None, 8, 8, 256)    1024        conv2d_910[0][0]
# __________________________________________________________________________________________________
# activation_1262 (Activation)    (None, 8, 8, 256)    0           batch_normalization_904[0][0]
# __________________________________________________________________________________________________
# add_365 (Add)                   (None, 8, 8, 256)    0           activation_1262[0][0]
#                                                                  activation_1260[0][0]
# __________________________________________________________________________________________________
# activation_1263 (Activation)    (None, 8, 8, 256)    0           add_365[0][0]
# __________________________________________________________________________________________________
# conv2d_911 (Conv2D)             (None, 8, 8, 256)    590080      activation_1263[0][0]
# __________________________________________________________________________________________________
# batch_normalization_905 (BatchN (None, 8, 8, 256)    1024        conv2d_911[0][0]
# __________________________________________________________________________________________________
# activation_1264 (Activation)    (None, 8, 8, 256)    0           batch_normalization_905[0][0]
# __________________________________________________________________________________________________
# conv2d_912 (Conv2D)             (None, 8, 8, 256)    590080      activation_1264[0][0]
# __________________________________________________________________________________________________
# batch_normalization_906 (BatchN (None, 8, 8, 256)    1024        conv2d_912[0][0]
# __________________________________________________________________________________________________
# activation_1265 (Activation)    (None, 8, 8, 256)    0           batch_normalization_906[0][0]
# __________________________________________________________________________________________________
# add_366 (Add)                   (None, 8, 8, 256)    0           activation_1265[0][0]
#                                                                  activation_1263[0][0]
# __________________________________________________________________________________________________
# activation_1266 (Activation)    (None, 8, 8, 256)    0           add_366[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_30 (Gl (None, 256)          0           activation_1266[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 6)            1542        global_average_pooling2d_30[0][0]
# ==================================================================================================
# Total params: 4,960,838
# Trainable params: 4,953,990
# Non-trainable params: 6,848
# __________________________________________________________________________________________________

# %% [markdown]
# ## Did you code in ResNet correctly?
# At the end of the summary you should see the following:
#
# Total params: 4,960,838
#
# Trainable params: 4,953,990
#
# Non-trainable params: 6,848

# %% [markdown]
# ## Resnet model description
# In the 'markdown' cell below replace `???` with your brief summary of your ResNet model architecture.

# %% [markdown]
# conv2D => batchno

# %% [markdown]
# ## Compile the ResNet model
# Note for the ResNet model we will use a lower learning rate of 0.0001 as opposed to the default value of 0.001 that we used for the LeNet model.

# %%
lr = 0.0001
ResNet.compile(optimizer=optimizers.Adam(lr=lr), 
               loss='categorical_crossentropy',
               metrics=['accuracy'])

# %% [markdown]
# ## Fit and evaluate the ResNet model

# %%
batch_size = 32
n_epochs = 50

history = ResNet.fit(X_train, Y_train,
                     batch_size=batch_size,
                     epochs=n_epochs,
                     validation_data=(X_valid, Y_valid),
                     verbose=2)

plot_history(history, 'ResNet')
valid_evaluate(ResNet, 'ResNet')
# Out:
# Train on 500 samples, validate on 160 samples
# Epoch 1/50
# 500/500 - 6s - loss: 2.3233 - accuracy: 0.4240 - val_loss: 19.4652 - val_accuracy: 0.2375
# Epoch 2/50
# 500/500 - 1s - loss: 1.3703 - accuracy: 0.7300 - val_loss: 3.4198 - val_accuracy: 0.3750
# Epoch 3/50
# 500/500 - 1s - loss: 1.1583 - accuracy: 0.8300 - val_loss: 2.5484 - val_accuracy: 0.3875
# Epoch 4/50
# 500/500 - 1s - loss: 1.0008 - accuracy: 0.9100 - val_loss: 2.7100 - val_accuracy: 0.4187
# Epoch 5/50
# 500/500 - 1s - loss: 0.9016 - accuracy: 0.9340 - val_loss: 4.4262 - val_accuracy: 0.4062
# Epoch 6/50
# 500/500 - 1s - loss: 0.8519 - accuracy: 0.9480 - val_loss: 6.5338 - val_accuracy: 0.2375
# Epoch 7/50
# 500/500 - 1s - loss: 0.7989 - accuracy: 0.9720 - val_loss: 7.1334 - val_accuracy: 0.2500
# Epoch 8/50
# 500/500 - 1s - loss: 0.7765 - accuracy: 0.9740 - val_loss: 7.4530 - val_accuracy: 0.2188
# Epoch 9/50
# 500/500 - 1s - loss: 0.7202 - accuracy: 1.0000 - val_loss: 6.0956 - val_accuracy: 0.2688
# Epoch 10/50
# 500/500 - 1s - loss: 0.7176 - accuracy: 0.9920 - val_loss: 6.7492 - val_accuracy: 0.2688
# Epoch 11/50
# 500/500 - 1s - loss: 0.7332 - accuracy: 0.9860 - val_loss: 6.0377 - val_accuracy: 0.3000
# Epoch 12/50
# 500/500 - 1s - loss: 0.7197 - accuracy: 0.9900 - val_loss: 7.5159 - val_accuracy: 0.2750
# Epoch 13/50
# 500/500 - 1s - loss: 0.7001 - accuracy: 1.0000 - val_loss: 7.9520 - val_accuracy: 0.2562
# Epoch 14/50
# 500/500 - 1s - loss: 0.7171 - accuracy: 0.9880 - val_loss: 6.8655 - val_accuracy: 0.3187
# Epoch 15/50
# 500/500 - 1s - loss: 0.7051 - accuracy: 0.9940 - val_loss: 8.0946 - val_accuracy: 0.2937
# Epoch 16/50
# 500/500 - 1s - loss: 0.6946 - accuracy: 1.0000 - val_loss: 8.0410 - val_accuracy: 0.2750
# Epoch 17/50
# 500/500 - 1s - loss: 0.6985 - accuracy: 0.9960 - val_loss: 6.2866 - val_accuracy: 0.3250
# Epoch 18/50
# 500/500 - 1s - loss: 0.7013 - accuracy: 0.9940 - val_loss: 7.4657 - val_accuracy: 0.3000
# Epoch 19/50
# 500/500 - 1s - loss: 0.6906 - accuracy: 0.9960 - val_loss: 6.1737 - val_accuracy: 0.3250
# Epoch 20/50
# 500/500 - 1s - loss: 0.6897 - accuracy: 1.0000 - val_loss: 5.8723 - val_accuracy: 0.3000
# Epoch 21/50
# 500/500 - 1s - loss: 0.6995 - accuracy: 0.9960 - val_loss: 11.0660 - val_accuracy: 0.2000
# Epoch 22/50
# 500/500 - 1s - loss: 0.8840 - accuracy: 0.9480 - val_loss: 5.3170 - val_accuracy: 0.3375
# Epoch 23/50
# 500/500 - 1s - loss: 0.7142 - accuracy: 0.9920 - val_loss: 9.0489 - val_accuracy: 0.2125
# Epoch 24/50
# 500/500 - 1s - loss: 0.7016 - accuracy: 0.9980 - val_loss: 6.2174 - val_accuracy: 0.4375
# Epoch 25/50
# 500/500 - 1s - loss: 0.6988 - accuracy: 0.9960 - val_loss: 5.2255 - val_accuracy: 0.3313
# Epoch 26/50
# 500/500 - 1s - loss: 0.6967 - accuracy: 0.9940 - val_loss: 6.4731 - val_accuracy: 0.4938
# Epoch 27/50
# 500/500 - 1s - loss: 0.6826 - accuracy: 1.0000 - val_loss: 3.6569 - val_accuracy: 0.5875
# Epoch 28/50
# 500/500 - 1s - loss: 0.6808 - accuracy: 1.0000 - val_loss: 3.4919 - val_accuracy: 0.6062
# Epoch 29/50
# 500/500 - 1s - loss: 0.6782 - accuracy: 1.0000 - val_loss: 3.9251 - val_accuracy: 0.5625
# Epoch 30/50
# 500/500 - 1s - loss: 0.6793 - accuracy: 1.0000 - val_loss: 2.2016 - val_accuracy: 0.7063
# Epoch 31/50
# 500/500 - 1s - loss: 0.6757 - accuracy: 1.0000 - val_loss: 2.6240 - val_accuracy: 0.6375
# Epoch 32/50
# 500/500 - 1s - loss: 0.6766 - accuracy: 1.0000 - val_loss: 2.3316 - val_accuracy: 0.6687
# Epoch 33/50
# 500/500 - 1s - loss: 0.6742 - accuracy: 1.0000 - val_loss: 1.5837 - val_accuracy: 0.7875
# Epoch 34/50
# 500/500 - 1s - loss: 0.6733 - accuracy: 1.0000 - val_loss: 1.5352 - val_accuracy: 0.7937
# Epoch 35/50
# 500/500 - 1s - loss: 0.6733 - accuracy: 1.0000 - val_loss: 1.4406 - val_accuracy: 0.8062
# Epoch 36/50
# 500/500 - 1s - loss: 0.6729 - accuracy: 1.0000 - val_loss: 1.4922 - val_accuracy: 0.8062
# Epoch 37/50
# 500/500 - 1s - loss: 0.6713 - accuracy: 1.0000 - val_loss: 1.3918 - val_accuracy: 0.8313
# Epoch 38/50
# 500/500 - 1s - loss: 0.6722 - accuracy: 1.0000 - val_loss: 1.4693 - val_accuracy: 0.7812
# Epoch 39/50
# 500/500 - 1s - loss: 0.6711 - accuracy: 1.0000 - val_loss: 1.3913 - val_accuracy: 0.8000
# Epoch 40/50
# 500/500 - 1s - loss: 0.6711 - accuracy: 0.9980 - val_loss: 2.8060 - val_accuracy: 0.6562
# Epoch 41/50
# 500/500 - 1s - loss: 0.6701 - accuracy: 1.0000 - val_loss: 1.3450 - val_accuracy: 0.8313
# Epoch 42/50
# 500/500 - 1s - loss: 0.6680 - accuracy: 1.0000 - val_loss: 1.0721 - val_accuracy: 0.8875
# Epoch 43/50
# 500/500 - 1s - loss: 0.6671 - accuracy: 1.0000 - val_loss: 1.0200 - val_accuracy: 0.9125
# Epoch 44/50
# 500/500 - 1s - loss: 0.6668 - accuracy: 1.0000 - val_loss: 1.0263 - val_accuracy: 0.9000
# Epoch 45/50
# 500/500 - 1s - loss: 0.6657 - accuracy: 1.0000 - val_loss: 0.9936 - val_accuracy: 0.9062
# Epoch 46/50
# 500/500 - 1s - loss: 0.6655 - accuracy: 1.0000 - val_loss: 1.0166 - val_accuracy: 0.9187
# Epoch 47/50
# 500/500 - 1s - loss: 0.6644 - accuracy: 1.0000 - val_loss: 0.9918 - val_accuracy: 0.9187
# Epoch 48/50
# 500/500 - 1s - loss: 0.6637 - accuracy: 1.0000 - val_loss: 0.9705 - val_accuracy: 0.9250
# Epoch 49/50
# 500/500 - 1s - loss: 0.6634 - accuracy: 1.0000 - val_loss: 1.0208 - val_accuracy: 0.9187
# Epoch 50/50
# 500/500 - 1s - loss: 0.6643 - accuracy: 0.9980 - val_loss: 1.1192 - val_accuracy: 0.8813
# classification report for validation data:
#               precision    recall  f1-score   support
#
#            0      0.737     1.000     0.848        28
#            1      0.846     0.786     0.815        14
#            2      0.923     0.947     0.935        38
#            3      1.000     0.773     0.872        22
#            4      0.871     1.000     0.931        27
#            5      1.000     0.710     0.830        31
#
#     accuracy                          0.881       160
#    macro avg      0.896     0.869     0.872       160
# weighted avg      0.900     0.881     0.880       160

# %% [markdown]
# ## Multiple runs of the same model
# Again, as we did for the LeNet model, re-run your ResNet model 5 times to compute the mean 'weighted avg f1-score'. Show this in the code cell below. For my five runs I got:
#
# (0.769 + 0.815 + 0.720 + 0.777 + 0.842) / 5 = 0.785

# %%
#(0.776 + 0.861 + 0.775 + 0.811 + 0.880) / 5 = 0.8206

# %% [markdown]
# ## Notes
# Your probably noticed that the training was quite eratic for your ResNet model above (i.e. the training curve was quite jaggedy). We could combat this with changes to the model architecture, the batch size and learning rate. We could also perhaps improve things with data augmentation. We will not explore these modifications here though.
#
# This was a big model that we trained, with almost 5 million parameters. With only 500 images for training this was rather ambitious! A better way to deal with a small dataset size, when we still want to fit a fairly complex and descriptive model (that will hopefully make good predictions), is to use transfer learning. This will be the focus of part 3 of the assignemnt.
